# %%
import pandas as pd
import numpy as np

# %%
extrator = []
for i in range(1,24):
    for k in range (1,42):
        if k==7:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B5.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==8:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B6.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==9:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B8.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==10:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B9.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==13:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B11.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==14:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B12.PLT', dtype= float, delimiter=' ',skip_header=49))
        else:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'.PLT', dtype= float, delimiter=' ',skip_header=49))
caso = 1
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5face0f10dfe> in <module>
#       3     for k in range (1,42):
#       4         if k==7:
# ----> 5             extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B5.PLT', dtype= float, delimiter=' ',skip_header=49))
#       6             extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
#       7         elif k==8:
#
# ...

# %%
extrator = []
for i in range(2,38):
    for k in range (1,42):
        if k==7:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B5.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==8:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B6.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==9:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B8.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==10:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B9.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==13:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B11.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==14:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B12.PLT', dtype= float, delimiter=' ',skip_header=49))
        else:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'.PLT', dtype= float, delimiter=' ',skip_header=49))
caso = 2

# %%
extrator = []
for i in range(2,21):
    for k in range (1,42):
        if k==7:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B5.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==8:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B6.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==9:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B8.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==10:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B9.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==13:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B11.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==14:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B12.PLT', dtype= float, delimiter=' ',skip_header=49))
        else:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'.PLT', dtype= float, delimiter=' ',skip_header=49))
caso = 3

# %%
extrator = []
for i in range(2,32):
    for k in range (1,42):
        if k==7:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B5.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==8:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B6.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==9:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B8.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==10:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B9.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==13:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B11.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==14:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B12.PLT', dtype= float, delimiter=' ',skip_header=49))
        else:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'.PLT', dtype= float, delimiter=' ',skip_header=49))
caso = 4

# %%
extrator = []
for i in range(2,18):
    for k in range (1,42):
        if k==7:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B5.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==8:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B6.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==9:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B8.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==10:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B9.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==13:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B11.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==14:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B12.PLT', dtype= float, delimiter=' ',skip_header=49))
        else:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'.PLT', dtype= float, delimiter=' ',skip_header=49))
caso = 5

# %%
extrator = []
for i in range(2,18):
    for k in range (1,42):
        if k==7:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B5.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==8:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B6.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==9:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B8.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==10:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B7.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B9.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==13:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B11.PLT', dtype= float, delimiter=' ',skip_header=49))
        elif k==14:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B10.PLT', dtype= float, delimiter=' ',skip_header=49))
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'B12.PLT', dtype= float, delimiter=' ',skip_header=49))
        else:
            extrator.append(np.genfromtxt('C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\CASO'+str(i).zfill(2)+'\\CASO'+str(i).zfill(2)+'_LINHA'+str(k)+'.PLT', dtype= float, delimiter=' ',skip_header=49))
caso = 6

# %%
data = []
data_split = []
#np.size(extrator)=1739
for i in range(np.size(extrator)):
    linha = (extrator[i].shape[0]*extrator[i].shape[1])/8
    data.append(extrator[i].reshape((int(linha),8)))
    n = data[i].shape[0]/6
    data_split.append(np.split(data[i],n))

# %%
y = pd.DataFrame([])
n0 = np.size(data_split)

Xd = pd.DataFrame([])#, columns = 'MQ1 MQ36 MQ35 MQ33 MQ32 MQ31 MQ26'.split())
XPa = pd.DataFrame([])
XPg = pd.DataFrame([])
XQg = pd.DataFrame([])
XVM = pd.DataFrame([])
XVA = pd.DataFrame([])

for i in range(n0):
    size=np.size(data_split[i])
    n=int(size/48)
    
    tempo = []
    delt = []
    p_ace = []
    p_ger = []
    q_ger = []
    v_mod = []
    v_ang = []
    tempo = []

    
    for k in range(n):
        
        tempo.append(data_split[i][k][0][0])
        delt.append(data_split[i][k][0][1:])
        p_ace.append(data_split[i][k][1])
        p_ger.append(data_split[i][k][2])
        q_ger.append(data_split[i][k][3])
        v_mod.append(data_split[i][k][4])
        v_ang.append(data_split[i][k][5])
        
    t = np.array(tempo)
    D = pd.DataFrame(list(delt), columns = 'D1 D36 D35 D33 D32 D31 D26'.split())
    Pa = pd.DataFrame(list(p_ace), columns = 'PA1 PA36 PA35 PA34 PA33 PA32 PA31 PA26'.split())
    Pg = pd.DataFrame(list(p_ger), columns = 'PG1 PG36 PG35 PG34 PG33 PG32 PG31 PG26'.split())
    Qg = pd.DataFrame(list(q_ger), columns = 'QG1 QG36 QG35 QG34 QG33 QG32 QG31 QG26'.split())
    VM = pd.DataFrame(list(v_mod), columns = 'VM1 VM36 VM35 VM34 VM33 VM32 VM31 VM26'.split())
    VA = pd.DataFrame(list(v_ang), columns = 'VA1 VA36 VA35 VA34 VA33 VA32 VA31 VA26'.split())
    
    if t.size == 517:
        y = y.append([0])
    else:
        y = y.append([1])
               
    Xd = Xd.append([D.describe()])#, columns = 'MQ1 MQ35 MQ35 MQ33 MQ32 MQ31 MQ26'.split())
    XPa = XPa.append([Pa.describe()])
    XPg = XPg.append([Pg.describe()])
    XQg = XQg.append([Qg.describe()])
    XVM = XVM.append([VM.describe()])
    XVA = XVA.append([VA.describe()])
    
if caso == 1:
    Xd.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\Xd.csv', index = True, header = True)
    XPa.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\XPa.csv', index = True, header = True)
    XPg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\XPg.csv', index = True, header = True)
    XQg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\XQg.csv', index = True, header = True)
    XVM.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\XVM.csv', index = True, header = True)
    XVA.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\XVA.csv',index = True, header = True)
    y.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso B\\y.csv',index = True, header = True)
elif caso == 2:
    Xd.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\Xd.csv', index = True, header = True)
    XPa.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\XPa.csv', index = True, header = True)
    XPg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\XPg.csv', index = True, header = True)
    XQg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\XQg.csv', index = True, header = True)
    XVM.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\XVM.csv', index = True, header = True)
    XVA.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\XVA.csv',index = True, header = True)
    y.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso A\\y.csv',index = True, header = True)
elif caso == 3:
    Xd.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\Xd.csv', index = True, header = True)
    XPa.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\XPa.csv', index = True, header = True)
    XPg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\XPg.csv', index = True, header = True)
    XQg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\XQg.csv', index = True, header = True)
    XVM.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\XVM.csv', index = True, header = True)
    XVA.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\XVA.csv',index = True, header = True)
    y.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso C\\y.csv',index = True, header = True)
    
elif caso == 4:
    Xd.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\Xd.csv', index = True, header = True)
    XPa.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\XPa.csv', index = True, header = True)
    XPg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\XPg.csv', index = True, header = True)
    XQg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\XQg.csv', index = True, header = True)
    XVM.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\XVM.csv', index = True, header = True)
    XVA.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\XVA.csv',index = True, header = True)
    y.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso D\\y.csv',index = True, header = True)

elif caso == 5:
    Xd.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\Xd.csv', index = True, header = True)
    XPa.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\XPa.csv', index = True, header = True)
    XPg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\XPg.csv', index = True, header = True)
    XQg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\XQg.csv', index = True, header = True)
    XVM.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\XVM.csv', index = True, header = True)
    XVA.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\XVA.csv',index = True, header = True)
    y.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso E\\y.csv',index = True, header = True)
    
elif caso == 6:
    Xd.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\Xd.csv', index = True, header = True)
    XPa.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\XPa.csv', index = True, header = True)
    XPg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\XPg.csv', index = True, header = True)
    XQg.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\XQg.csv', index = True, header = True)
    XVM.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\XVM.csv', index = True, header = True)
    XVA.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\XVA.csv',index = True, header = True)
    y.to_csv(r'C:\\Users\\Pablo\\Desktop\\tfc\\Simulações\\Caso F\\y.csv',index = True, header = True)
